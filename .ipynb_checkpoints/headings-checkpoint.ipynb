# %%
import pandas as pd
import numpy as np

path = 'unionv02.csv'
db = pd.read_csv(path, sep=",")

#db

# %%
heading4 = db[(db.heading4.isnull()==False)]
#heading4
heading4.groupby(['sensor']).mean()
#heading4.to_csv('heading4.csv',index=False)
#heading4.shape

# %%
heading5 = db[(db.heading5.isnull()==False)]
#heading5
heading5.groupby(['sensor']).mean()
#heading5.to_csv('heading5.csv',index=False)
#heading5.shape

# %%
heading6 = db[(db.heading6.isnull()==False)]
#heading6
heading6.groupby(['sensor']).mean()
#heading6.to_csv('heading6.csv',index=False)
#heading6.shape

# %%
db.columns

# %%
accelerometer = db[(db.sensor=='Accelerometer')]
accelerometer = accelerometer.drop(columns=['heading4', 'heading5', 'heading6'])
accelerometer.rename(columns={'rssi/x': 'ax', 'y': 'ay', 'z': 'az'}, inplace=True)
accelerometer.columns

# %%
gyroscope = db[(db.sensor=='Gyroscope')]
gyroscope = gyroscope.drop(columns=['heading4', 'heading5', 'heading6'])
gyroscope.rename(columns={'rssi/x': 'gx', 'y': 'gy', 'z': 'gz'}, inplace=True)
gyroscope.columns

# %%
attitude = db[(db.sensor=='Attitude')]
attitude = attitude.drop(columns=['heading4', 'heading5', 'heading6'])
attitude.rename(columns={'rssi/x': 'pitch', 'y': 'roll', 'z': 'yaw'}, inplace=True)
attitude.columns

# %%
gravity = db[(db.sensor=='Gravity')]
gravity = gravity.drop(columns=['heading4', 'heading5', 'heading6'])
gravity.rename(columns={'rssi/x': 'x', 'y': 'y', 'z': 'z'}, inplace=True)
gravity.columns

# %%
magnetic = db[(db.sensor=='Magnetic-field')]
magnetic = magnetic.drop(columns=['heading5', 'heading6'])
magnetic.rename(columns={'rssi/x': 'x', 'y': 'y', 'z': 'z', 'heading4' : 'accuracy'}, inplace=True)
magnetic.columns

# %%
altitude = db[(db.sensor=='Altitude')]
altitude = altitude.drop(columns=['z','heading4','heading5', 'heading6'])
altitude.rename(columns={'rssi/x': 'x', 'y': 'y'}, inplace=True)
altitude.columns

# %%
activity = db[(db.sensor=='Activity')]
activity = activity.drop(columns=['heading4','heading5', 'heading6'])
activity.rename(columns={'rssi/x': 'start_time', 'y': 'activity_type', 'z': 'confidence_level'}, inplace=True)
activity.columns

# %%
heading = db[(db.sensor=='Heading')]
heading.rename(columns={'rssi/x': 'true_heading', 'y': 'magnetic_heading', 'z': 'heading_accuracy'
                       , 'heading4': 'x', 'heading5': 'y', 'heading6': 'z'}, inplace=True)
heading.columns

# %%
bluetooth = db[(db.sensor=='Bluetooth')]
bluetooth = bluetooth.drop(columns=['y','z','heading4','heading5', 'heading6'])
bluetooth.rename(columns={'rssi/x': 'rssi', 'y': 'activity_type', 'z': 'confidence_level'}, inplace=True)
bluetooth.columns

# %%
#sensores = ['bluetooth.csv', 'accelerometer.csv','gyroscope.csv','attitude.csv','gravity.csv','magnetic-field.csv','altitude.csv','activity.csv','heading.csv']
with open('sensores.txt', 'r') as f:
    txtsensores = [tsensor.split() for tsensor in f]
    
dsensores = [['y','z','heading4','heading5', 'heading6'],
             ['heading4', 'heading5', 'heading6'],
             ['heading4', 'heading5', 'heading6'],
             ['heading4', 'heading5', 'heading6'],
             ['heading4', 'heading5', 'heading6'],
             ['heading5', 'heading6'],
             ['z','heading4','heading5', 'heading6'],
             ['heading4','heading5', 'heading6'],
             [],
             ['time', 'sensor', 'rssi', 'file', 'phone_carriage_state', 'TXDevice',
       'TXcarry', 'TXpose', 'TXPower', 'RXDivice', 'RXcarry', 'RXpose',
       'distance_in_meters', 'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'ax', 'ay', 'az', 'file', 'phone_carriage_state',
       'TXDevice', 'TXcarry', 'TXpose', 'TXPower', 'RXDivice', 'RXcarry',
       'RXpose', 'distance_in_meters', 'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'gx', 'gy', 'gz', 'file', 'phone_carriage_state',
       'TXDevice', 'TXcarry', 'TXpose', 'TXPower', 'RXDivice', 'RXcarry',
       'RXpose', 'distance_in_meters', 'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'pitch', 'roll', 'yaw', 'file',
       'phone_carriage_state', 'TXDevice', 'TXcarry', 'TXpose', 'TXPower',
       'RXDivice', 'RXcarry', 'RXpose', 'distance_in_meters',
       'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'x', 'y', 'z', 'file', 'phone_carriage_state',
       'TXDevice', 'TXcarry', 'TXpose', 'TXPower', 'RXDivice', 'RXcarry',
       'RXpose', 'distance_in_meters', 'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'x', 'y', 'z', 'accuracy', 'file',
       'phone_carriage_state', 'TXDevice', 'TXcarry', 'TXpose', 'TXPower',
       'RXDivice', 'RXcarry', 'RXpose', 'distance_in_meters',
       'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'x', 'y', 'file', 'phone_carriage_state', 'TXDevice',
       'TXcarry', 'TXpose', 'TXPower', 'RXDivice', 'RXcarry', 'RXpose',
       'distance_in_meters', 'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'start_time', 'activity_type', 'confidence_level',
       'file', 'phone_carriage_state', 'TXDevice', 'TXcarry', 'TXpose',
       'TXPower', 'RXDivice', 'RXcarry', 'RXpose', 'distance_in_meters',
       'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'true_heading', 'magnetic_heading',
       'heading_accuracy', 'x', 'y', 'z', 'file', 'phone_carriage_state',
       'TXDevice', 'TXcarry', 'TXpose', 'TXPower', 'RXDivice', 'RXcarry',
       'RXpose', 'distance_in_meters', 'step_size_in_sec', 'coarse_grain']]

#with open('archivo.txt', 'r') as f:
#    lineas = [linea.split() for linea in f]


for i in range(int(len(dsensores)/2)-1):
    sensor = (txtsensores[i][:-4])
    #sensor = (txtsensores[i])
    print(sensor)
    #print(sensor.capitalize())
    #prueba = db[(db.sensor==sensor.capitalize())]
    #prueba = prueba.drop(columns=dsensores[i])
    #prueba.columns=dsensores[i+9]
    #prueba.to_csv(txtsensores[i],index=False)

    
#prueba

# %%
dsensores = [['y','z','heading4','heading5', 'heading6'],
             ['heading4', 'heading5', 'heading6'],
             ['heading4', 'heading5', 'heading6'],
             ['heading4', 'heading5', 'heading6'],
             ['heading4', 'heading5', 'heading6'],
             ['heading5', 'heading6'],
             ['z','heading4','heading5', 'heading6'],
             ['heading4','heading5', 'heading6']]
dsensores[5]

# %%
dsensores = [['y','z','heading4','heading5', 'heading6'],
             ['heading4', 'heading5', 'heading6'],
             ['heading4', 'heading5', 'heading6'],
             ['heading4', 'heading5', 'heading6'],
             ['heading4', 'heading5', 'heading6'],
             ['heading5', 'heading6'],
             ['z','heading4','heading5', 'heading6'],
             ['heading4','heading5', 'heading6'],
             [],
             ['time', 'sensor', 'rssi', 'file', 'phone_carriage_state', 'TXDevice',
       'TXcarry', 'TXpose', 'TXPower', 'RXDivice', 'RXcarry', 'RXpose',
       'distance_in_meters', 'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'ax', 'ay', 'az', 'file', 'phone_carriage_state',
       'TXDevice', 'TXcarry', 'TXpose', 'TXPower', 'RXDivice', 'RXcarry',
       'RXpose', 'distance_in_meters', 'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'gx', 'gy', 'gz', 'file', 'phone_carriage_state',
       'TXDevice', 'TXcarry', 'TXpose', 'TXPower', 'RXDivice', 'RXcarry',
       'RXpose', 'distance_in_meters', 'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'pitch', 'roll', 'yaw', 'file',
       'phone_carriage_state', 'TXDevice', 'TXcarry', 'TXpose', 'TXPower',
       'RXDivice', 'RXcarry', 'RXpose', 'distance_in_meters',
       'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'x', 'y', 'z', 'file', 'phone_carriage_state',
       'TXDevice', 'TXcarry', 'TXpose', 'TXPower', 'RXDivice', 'RXcarry',
       'RXpose', 'distance_in_meters', 'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'x', 'y', 'z', 'accuracy', 'file',
       'phone_carriage_state', 'TXDevice', 'TXcarry', 'TXpose', 'TXPower',
       'RXDivice', 'RXcarry', 'RXpose', 'distance_in_meters',
       'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'x', 'y', 'file', 'phone_carriage_state', 'TXDevice',
       'TXcarry', 'TXpose', 'TXPower', 'RXDivice', 'RXcarry', 'RXpose',
       'distance_in_meters', 'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'start_time', 'activity_type', 'confidence_level',
       'file', 'phone_carriage_state', 'TXDevice', 'TXcarry', 'TXpose',
       'TXPower', 'RXDivice', 'RXcarry', 'RXpose', 'distance_in_meters',
       'step_size_in_sec', 'coarse_grain'],
             ['time', 'sensor', 'true_heading', 'magnetic_heading',
       'heading_accuracy', 'x', 'y', 'z', 'file', 'phone_carriage_state',
       'TXDevice', 'TXcarry', 'TXpose', 'TXPower', 'RXDivice', 'RXcarry',
       'RXpose', 'distance_in_meters', 'step_size_in_sec', 'coarse_grain']]

#len(dsensores)
dsensores[0]

# %%
#dsensores
prueba.columns=dsensores[9]
prueba

# %%
int(len(dsensores)/2)

# %%
with open('sdrop.txt', 'r') as f:
    sdrop = [str(dsensor.split(';')) for dsensor in f]

#type(txtsensores[1])
#print(txtsensores[8])
#print(txtsensores[8][2:-6].capitalize())
sensor = (sdrop[0][2:-4])
print(sensor)
    
#sensores = ['bluetooth.csv', 'accelerometer.csv','gyroscope.csv','attitude.csv','gravity.csv','magnetic-field.csv','altitude.csv','activity.csv','heading.csv']
#type(sensores[1])
# Out:
# ['y','z','heading4','heading5', 'heading6']

# %%
with open('sensores.txt', 'r') as f:
    sensores = [str(lsensor.split(';')) for lsensor in f]

csv_file = np.genfromtxt('dsensores.csv', 
                          delimiter=',', dtype=str)
#top_row = csv_file[:].tolist()
top_row = csv_file[:,0].tolist() 
    
for i in range(int(len(sensores))):
    dbl = db[(db.sensor==sensores[i][2:-8].capitalize())]
    print(sdrop[i][2:-4])
    drop = (sdrop[i][3:-5])
    print(drop)
    dbl = dbl.drop(columns=csv_file[i])
        
#dbl
    
                         
#prueba.columns=dsensores[i+9]
#prueba.to_csv(txtsensores[i],index=False)
# Out:
# '['y','z','heading4','heading5', 'heading6']'
# ['y','z','heading4','heading5', 'heading6']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-96806985ecdc> in <module>
#      10     drop = (sdrop[i][3:-5])
#      11     print(drop)
# ---> 12     dbl = dbl.drop(columns=drop)
#      13
#      14 #dbl
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: '["[\'y\',\'z\',\'heading4\',\'heading5\', \'heading6\']"] not found in axis'

# %%
prueba

# %%
with open('sensores.txt', 'r') as f:
    sensores = [str(lsensor.split(';')) for lsensor in f]
    
for i in range(int(len(sensores))):
    dbl = db[(db.sensor==sensores[i][2:-8].capitalize())]
        
dbl
# Out:
#             time   sensor      rssi/x                   y          z  \
# 668      220.034  Heading  263.972900  278.36737060546875  13.915518
# 851        0.345  Heading  310.403198  324.58087158203125  15.229493
# 915        1.397  Heading  315.615112  329.79278564453125  15.236019
# 1126      92.435  Heading  221.979034  236.15670776367188  15.202652
# 1716     255.599  Heading  337.049927  351.22760009765625  15.247413
# ...          ...      ...         ...                 ...        ...
# 1591561  188.594  Heading  212.405548  226.80001831054688  14.471004
# 1591577  188.894  Heading  207.315094  221.70956420898438  14.460403
# 1591604  189.444  Heading  201.650772   216.0452423095703  14.430926
# 1591954  208.576  Heading  254.569672   268.9641418457031  14.439457
# 1592423  250.762  Heading   26.576513  40.970985412597656  14.260417
#
#                     heading4   heading5   heading6                  file  \
# 668         11.5321044921875 -22.226871 -31.625895  abgikaek_tc4tl20.csv
# 851       19.372005462646484  44.041664  23.271210  acehqsss_tc4tl20.csv
# 915       18.002656936645508  46.341431  18.742157  acehqsss_tc4tl20.csv
# 1126      26.752248764038086  41.694542  -9.173370  acehqsss_tc4tl20.csv
# 1716       9.257770538330078  46.276932  24.394958  acehqsss_tc4tl20.csv
# ...                      ...        ...        ...                   ...
# 1591561   11.133148193359375 -24.588398 -36.556892  zzxttrqc_tc4tl20.csv
# 1591577    9.399322509765625 -24.932613 -36.406380  zzxttrqc_tc4tl20.csv
# 1591604    5.670562744140625 -24.858566 -38.143505  zzxttrqc_tc4tl20.csv
# 1591954   17.871429443359375 -13.953186 -39.643093  zzxttrqc_tc4tl20.csv
# 1592423  -10.648468017578125 -12.450783 -42.281654  zzxttrqc_tc4tl20.csv
#
#         phone_carriage_state  TXDevice  TXcarry    TXpose  TXPower  \
# 668          unknown_unknown  iPhone11  unknown   unknown        8
# 851            pocket_pocket  iPhoneXS   pocket  standing       12
# 915            pocket_pocket  iPhoneXS   pocket  standing       12
# 1126           pocket_pocket  iPhoneXS   pocket  standing       12
# 1716           pocket_pocket  iPhoneXS   pocket  standing       12
# ...                      ...       ...      ...       ...      ...
# 1591561            hand_hand  iPhone11     hand   sitting        8
# 1591577            hand_hand  iPhone11     hand   sitting        8
# 1591604            hand_hand  iPhone11     hand   sitting        8
# 1591954            hand_hand  iPhone11     hand   sitting        8
# 1592423            hand_hand  iPhone11     hand   sitting        8
#
#                  RXDivice  RXcarry    RXpose  distance_in_meters  \
# 668      iPhone11_Pro_max  unknown   unknown                 1.2
# 851               iPhone8   pocket  standing                 4.5
# 915               iPhone8   pocket  standing                 4.5
# 1126              iPhone8   pocket  standing                 4.5
# 1716              iPhone8   pocket  standing                 4.5
# ...                   ...      ...       ...                 ...
# 1591561  iPhone11_Pro_max     hand   sitting                 3.0
# 1591577  iPhone11_Pro_max     hand   sitting                 3.0
# 1591604  iPhone11_Pro_max     hand   sitting                 3.0
# 1591954  iPhone11_Pro_max     hand   sitting                 3.0
# 1592423  iPhone11_Pro_max     hand   sitting                 3.0
#
#          step_size_in_sec coarse_grain
# 668                  60.0            N
# 851                  80.0            Y
# 915                  80.0            Y
# 1126                 80.0            Y
# 1716                 80.0            Y
# ...                   ...          ...
# 1591561              10.0            N
# 1591577              10.0            N
# 1591604              10.0            N
# 1591954              10.0            N
# 1592423              10.0            N
#
# [11294 rows x 20 columns]

# %%
import numpy as np
csv_file = np.genfromtxt('dsensores.csv', 
                          delimiter=',', dtype=str)
#top_row = csv_file[:].tolist()
top_row = csv_file[:,0].tolist()
csv_file[5]
# Out:
# array(['heading5', 'heading6', '', '', ''], dtype='<U8')
